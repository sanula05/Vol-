# %%
import random 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Genatating Intrest Rates Using Stochastic Modelling Techniques

# %%
np.random.seed(42)

# %%
def Random_rates(num_elm,num_set):
    t_r = []
    x = 0
    for z in range(num_set):
        r_r = []
        for i in range(num_elm):
            x = (np.random.lognormal(mean=0.0, sigma=1.0, size=None))
         

            r_r.append((x**2)**0.5)
        t_r.append(r_r)
    
    return t_r
    # for row in t_r:
    #     plt.plot(row)
    
    # plt.xlabel("Time")
    # plt.ylabel("Rates")
    # plt.title("Intrest Rates")
    # plt.show()
    
    
        
    return t_r
def Avr_rate(arr):
    arr = np.array(arr)
    col_avgs = arr.mean(axis=0)
    return col_avgs

def Shock(arr,mean,std_dev,n_samples):

    shocks = np.random.normal(mean, std_dev, n_samples)
    # plt.plot(shocks)
    # plt.show()
    return shocks

def Reg_model(arr,n):
    y_val = arr
    x_val =[]
    x_mean = 0
    for i in range(n):
        x_val.append(i)
    for i in range(len(x_val)):
        x_mean += i
    x_mean = x_mean/len(x_val)
    y_mean = arr.mean(axis=0)
    x_val = np.array(x_val)
    b_u = 0
    b_l = 0
    for i in range(n):
        b_u = (x_val[i]-x_mean)*(y_val[i]-y_mean)
        b_l = (x_val[i]-x_mean)**2
    b_1 = b_u/b_l
    b_0 = y_mean-b_1*x_mean
    y = x_val * b_1 + b_0
    plt.plot(x_val,y)
    plt.title("Linear Reggresion Model")
    plt.show()

def Seasonal_component(arr):
 
 pass



    



plt.plot(Random_rates(100,100))
plt.title("Random Rates")
plt.show()
plt.plot(Avr_rate(Random_rates(100,100)))
plt.title("Avarage  Rate")
plt.show()
plt.plot(Shock(Avr_rate(Random_rates(100,100)),0,1,100))
plt.title("Random Shock")
plt.show()
print(Reg_model(Avr_rate(Random_rates(100,100)),100))
# Out:
# None

# %%
# Consumer Credit
