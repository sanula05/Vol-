# %%
import numpy as np
import matplotlib.pyplot as plt

X_t_0 = 0
X_t_T = []
time_scale = []
b = 1000
lambda_ = 3
mew = 2
B_i = []
D_i = []
arr = []
for i in range(b):
    B_i.append(np.random.exponential(lambda_))
    D_i.append(np.random.exponential(mew))
B_i.sort()
D_i.sort()
for i in range(2*b):
    if B_i[1]>D_i[1]:
        X_t_0 = X_t_0 - 1
        X_t_T.append(X_t_0)
        time_scale.append(D_i[1])
        D_i.pop(1)
    if np.min(D_i)>np.min(B_i):
        X_t_0 = X_t_0 + 1
        X_t_T.append(X_t_0)
        time_scale.append(B_i[1])
        B_i.pop(1)
    else:
     
     pass   
plt.plot(time_scale,X_t_T)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 19
#      17 D_i.sort()
#      18 for i in range(2*b):
# ---> 19     if B_i[1]>D_i[1]:
#      20         X_t_0 = X_t_0 - 1
#      21         X_t_T.append(X_t_0)
#
# IndexError: list index out of range
